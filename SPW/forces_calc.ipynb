# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("forces.xvg",skiprows=119,comments="@")
data.shape

A=9

x=data[:,0]
y=data[:,3::3]
y_na=data[:,3:48:3]
y_cl=data[:,51:96:3]

meanf_y=np.mean(y)
osmP=meanf_y/A

print(meanf_y)
print(osmP)

plt.title('Force (Z-axis) on Ions (1M NaCl) vs Time')
plt.xlabel('Time (ps)')
plt.ylabel('Force (kJ/mol nm)')
plt.plot(x,y)
# Out:
# 2.900901575457317
# 0.32232239727303524
# ...
